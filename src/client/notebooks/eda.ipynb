# %%
# !pip install s3fs
# Out:
# Collecting s3fs
#   Downloading s3fs-2022.8.2-py3-none-any.whl (27 kB)
# Collecting aiobotocore~=2.4.0
#   Downloading aiobotocore-2.4.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.1-cp37-cp37m-macosx_10_9_x86_64.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.9/570.9 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Collecting fsspec==2022.8.2
#   Downloading fsspec-2022.8.2-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 kB 3.2 MB/s eta 0:00:00a 0:00:01
# Collecting aioitertools>=0.5.1
#   Downloading aioitertools-0.10.0-py3-none-any.whl (23 kB)
# Collecting botocore<1.27.60,>=1.27.59
#   Downloading botocore-1.27.59-py3-none-any.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 9.2 MB/s eta 0:00:0000:0100:01
# Collecting wrapt>=1.10.10
#   Downloading wrapt-1.14.1-cp37-cp37m-macosx_10_9_x86_64.whl (34 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.3.0)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-macosx_10_9_x86_64.whl (28 kB)
# Collecting asynctest==0.13.0
#   Using cached asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.1-cp37-cp37m-macosx_10_9_x86_64.whl (36 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (22.1.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.1-cp37-cp37m-macosx_10_9_x86_64.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 1.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.0->s3fs) (1.26.12)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.0->s3fs) (2.8.2)
# Collecting jmespath<2.0.0,>=0.7.1
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: idna>=2.0 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.3)
# Requirement already satisfied: six>=1.5 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.0->s3fs) (1.16.0)
# Installing collected packages: wrapt, multidict, jmespath, fsspec, frozenlist, asynctest, async-timeout, aioitertools, yarl, botocore, aiosignal, aiohttp, aiobotocore, s3fs
# Successfully installed aiobotocore-2.4.0 aiohttp-3.8.1 aioitertools-0.10.0 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 botocore-1.27.59 frozenlist-1.3.1 fsspec-2022.8.2 jmespath-1.0.1 multidict-6.0.2 s3fs-2022.8.2 wrapt-1.14.1 yarl-1.8.1

# %%
# !pip install Pillow
# Out:
# Collecting Pillow
#   Downloading Pillow-9.2.0-cp37-cp37m-macosx_10_10_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 8.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: Pillow
# Successfully installed Pillow-9.2.0

# %%
# !pip install ipyplot
# Out:
# Collecting ipyplot
#   Downloading ipyplot-1.1.1-py3-none-any.whl (13 kB)
# Collecting shortuuid
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: numpy in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from ipyplot) (1.21.6)
# Requirement already satisfied: IPython in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from ipyplot) (7.34.0)
# Requirement already satisfied: pillow in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from ipyplot) (9.2.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (5.3.0)
# Requirement already satisfied: appnope in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (0.1.3)
# Requirement already satisfied: pexpect>4.3 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (3.0.30)
# Requirement already satisfied: pygments in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (2.13.0)
# Requirement already satisfied: matplotlib-inline in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (0.1.6)
# Requirement already satisfied: decorator in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (63.4.1)
# Requirement already satisfied: backcall in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from IPython->ipyplot) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from jedi>=0.16->IPython->ipyplot) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from pexpect>4.3->IPython->ipyplot) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/pierre.krzisch/miniforge3/envs/tcc-env/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->ipyplot) (0.2.5)
# Installing collected packages: shortuuid, ipyplot
# Successfully installed ipyplot-1.1.1 shortuuid-1.0.9

# %%
import os
import s3fs
import json
import time
import random
import requests
import pprint

import numpy as np
import pandas as pd

from PIL import Image
from ipyplot import plot_images

# %% [markdown]
# ### Helpers

# %%
S3_ENDPOINT = f'http://{os.getenv("S3_HOST")}:4566'
API_ENDPOINT = f'http://{os.getenv("API_HOST")}:5000'

# %%
s3 = s3fs.S3FileSystem(client_kwargs={'endpoint_url': f'http://{os.getenv("S3_HOST")}:4566'})

# %%
performed_tasks = {}
def perform_task(params, endpoint):
    api_response = requests.post(f"{API_ENDPOINT}/{endpoint}", json=params).json()
    print(api_response)
    task_id = api_response['task_id']
    
    status = 'PENDING'
    print("Processing...")
    while status == 'PENDING':
        time.sleep(3)
        response = requests.get(f'{API_ENDPOINT}/task/{task_id}').json()
        print(response)
        status = response['status']
        
    performed_tasks[task_id] = {
        'params': params,
        'status': status,
        'result': response['result']
    }
        
    if status != 'SUCCESS':
        raise Exception(response)
    else:
        print("Task complete!")
        
    return response['result']['s3_target']

# %%
def draw_images(items, source_folder, sample=3):
    sample_items = random.sample(items, sample)
    
    images = []
    for item in sample_items:
        with s3.open(f'{source_folder}/{item["image_id"]}.jpg') as f:
            images.append(np.asarray(Image.open(f)))
            
    plot_images(images, labels=[item['image_id'] for item in sample_items], custom_texts=[pprint.pformat(item) for item in sample_items], zoom_scale=1.0)

# %% [markdown]
# ## Task 1:
#
# Query for men's shoes based on date.

# %%
LIMIT = 10
YEAR = 2012

payload = {
    "gender": "Men", 
    "sub_category": "Shoes", 
    "start_year": YEAR,
    "limit": LIMIT,
}
s3_target = perform_task(payload, "filter")

# filter results
with s3.open(f'{s3_target}/metadata.json') as f:
    metadata = json.load(f)

# sample of original images
draw_images(metadata, f'{s3_target}/images')
# Out:
# {'task_id': 'afae3ac8-2c88-4937-9b98-2aa7fec42920'}
# Processing...
# {'id': 'afae3ac8-2c88-4937-9b98-2aa7fec42920', 'status': 'SUCCESS', 'error': None, 'result': {'s3_target': 's3://fashion-tasks/afae3ac8-2c88-4937-9b98-2aa7fec42920'}}
# Task complete!
#     <style>
#         #ipyplot-html-viewer-toggle-RnBg9XxkSkLoqPxGQx9B3C {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RnBg9XxkSkLoqPxGQx9B3C {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RnBg9XxkSkLoqPxGQx9B3C {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RnBg9XxkSkLoqPxGQx9B3C:checked ~ #ipyplot-html-viewer-textarea-RnBg9XxkSkLoqPxGQx9B3C {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RnBg9XxkSkLoqPxGQx9B3C:checked + #ipyplot-html-viewer-label-RnBg9XxkSkLoqPxGQx9B3C:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-RnBg9XxkSkLoqPxGQx9B3C">
#         <label id="ipyplot-html-viewer-label-RnBg9XxkSkLoqPxGQx9B3C" for="ipyplot-html-viewer-toggle-RnBg9XxkSkLoqPxGQx9B3C">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-RnBg9XxkSkLoqPxGQx9B3C" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-WtJG9EkbB4CnuJWrjWVzvx {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WtJG9EkbB4CnuJWrjWVzvx {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WtJG9EkbB4CnuJWrjWVzvx">
#     <div class="ipyplot-placeholder-div-WtJG9EkbB4CnuJWrjWVzvx">
#         <div id="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-3HQk7nhnWzP2B5oPzToE8X" class="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx">
#             <h4 style="font-size: 12px; word-wrap: break-word;">49461</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Blue',
#  'display_name': 'Vans Men Blue Era Scilla Plaid Shoes',
#  'gender': 'Men',
#  'image_id': 49461,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-3HQk7nhnWzP2B5oPzToE8X">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtJG9EkbB4CnuJWrjWVzvx">
#         <div id="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-cgkiF2xJwDz4PkNcjU8VpG" class="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx">
#             <h4 style="font-size: 12px; word-wrap: break-word;">33822</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'White',
#  'display_name': 'Puma Men Axis White & Grey Sports Shoes',
#  'gender': 'Men',
#  'image_id': 33822,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-cgkiF2xJwDz4PkNcjU8VpG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtJG9EkbB4CnuJWrjWVzvx">
#         <div id="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-jCd5yLVPfCzoMVxWaLqXFR" class="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx">
#             <h4 style="font-size: 12px; word-wrap: break-word;">34835</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'Blue',
#  'display_name': 'ADIDAS Men Blue Chill Sports Shoes',
#  'gender': 'Men',
#  'image_id': 34835,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-jCd5yLVPfCzoMVxWaLqXFR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-WtJG9EkbB4CnuJWrjWVzvx {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WtJG9EkbB4CnuJWrjWVzvx {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WtJG9EkbB4CnuJWrjWVzvx">
#     <div class="ipyplot-placeholder-div-WtJG9EkbB4CnuJWrjWVzvx">
#         <div id="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-3HQk7nhnWzP2B5oPzToE8X" class="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx">
#             <h4 style="font-size: 12px; word-wrap: break-word;">49461</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Blue',
#  'display_name': 'Vans Men Blue Era Scilla Plaid Shoes',
#  'gender': 'Men',
#  'image_id': 49461,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-3HQk7nhnWzP2B5oPzToE8X">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtJG9EkbB4CnuJWrjWVzvx">
#         <div id="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-cgkiF2xJwDz4PkNcjU8VpG" class="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx">
#             <h4 style="font-size: 12px; word-wrap: break-word;">33822</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'White',
#  'display_name': 'Puma Men Axis White & Grey Sports Shoes',
#  'gender': 'Men',
#  'image_id': 33822,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-cgkiF2xJwDz4PkNcjU8VpG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtJG9EkbB4CnuJWrjWVzvx">
#         <div id="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-jCd5yLVPfCzoMVxWaLqXFR" class="ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx">
#             <h4 style="font-size: 12px; word-wrap: break-word;">34835</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'Blue',
#  'display_name': 'ADIDAS Men Blue Chill Sports Shoes',
#  'gender': 'Men',
#  'image_id': 34835,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtJG9EkbB4CnuJWrjWVzvx-jCd5yLVPfCzoMVxWaLqXFR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## Task 2:
#
# Run the same query, but now do augmentation to the images based on the given configuration

# %%
payload = {
    "gender": "Men", 
    "sub_category": "Shoes", 
    "start_year": YEAR,
    "limit": LIMIT,
    "augmentation_config": {'albumentation': {
        'input_image': {'width': 60, 'height': 80}, 
        'cropping': {'height': {'min': 10, 'max': 70}}, 
        'resize': {'width': 256, 'height': 256}}}
}
s3_target = perform_task(payload, "filter")

# filter results
with s3.open(f'{s3_target}/metadata.json') as f:
    metadata = json.load(f)

# sample of original images
draw_images(metadata, f'{s3_target}/images', sample=LIMIT)

# sample of transformed images
draw_images(metadata, f'{s3_target}/augmentation', sample=LIMIT)
# Out:
# {'task_id': '2d4d6ec4-3f4d-4f68-8c6d-f7c58007aab9'}
# Processing...
# {'id': '2d4d6ec4-3f4d-4f68-8c6d-f7c58007aab9', 'status': 'SUCCESS', 'error': None, 'result': {'s3_target': 's3://fashion-tasks/2d4d6ec4-3f4d-4f68-8c6d-f7c58007aab9'}}
# Task complete!
#     <style>
#         #ipyplot-html-viewer-toggle-7G66TsEPbrA5VWUe7KAA8M {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-7G66TsEPbrA5VWUe7KAA8M {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-7G66TsEPbrA5VWUe7KAA8M {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-7G66TsEPbrA5VWUe7KAA8M:checked ~ #ipyplot-html-viewer-textarea-7G66TsEPbrA5VWUe7KAA8M {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-7G66TsEPbrA5VWUe7KAA8M:checked + #ipyplot-html-viewer-label-7G66TsEPbrA5VWUe7KAA8M:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-7G66TsEPbrA5VWUe7KAA8M">
#         <label id="ipyplot-html-viewer-label-7G66TsEPbrA5VWUe7KAA8M" for="ipyplot-html-viewer-toggle-7G66TsEPbrA5VWUe7KAA8M">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-7G66TsEPbrA5VWUe7KAA8M" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-ALAS2YGz2W5kGVTT99uH9F {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ALAS2YGz2W5kGVTT99uH9F">
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-dq9N5zNtds33yNv2ibePgP" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">34835</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'Blue',
#  'display_name': 'ADIDAS Men Blue Chill Sports Shoes',
#  'gender': 'Men',
#  'image_id': 34835,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-dq9N5zNtds33yNv2ibePgP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-D8Rm63c37pJbhdAXrExjAa" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">33822</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'White',
#  'display_name': 'Puma Men Axis White & Grey Sports Shoes',
#  'gender': 'Men',
#  'image_id': 33822,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-D8Rm63c37pJbhdAXrExjAa">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-gCw9N97dKJmNeXPXApn94e" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">22198</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Timberland Men Black Casual Shoes',
#  'gender': 'Men',
#  'image_id': 22198,
#  'master_category': 'Footwear',
#  'season': 'Fall',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-gCw9N97dKJmNeXPXApn94e">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-FK5JfxLrUnmb8zorxARhCd" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">59435</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Formal Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Arrow Men Black Formal Shoes',
#  'gender': 'Men',
#  'image_id': 59435,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Formal',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-FK5JfxLrUnmb8zorxARhCd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-a6bcwsqmGqUsDWdrkDigkn" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">49461</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Blue',
#  'display_name': 'Vans Men Blue Era Scilla Plaid Shoes',
#  'gender': 'Men',
#  'image_id': 49461,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a hr
#         <style>
#         #ipyplot-imgs-container-div-ALAS2YGz2W5kGVTT99uH9F {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ALAS2YGz2W5kGVTT99uH9F">
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-dq9N5zNtds33yNv2ibePgP" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">34835</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'Blue',
#  'display_name': 'ADIDAS Men Blue Chill Sports Shoes',
#  'gender': 'Men',
#  'image_id': 34835,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-dq9N5zNtds33yNv2ibePgP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-D8Rm63c37pJbhdAXrExjAa" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">33822</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'White',
#  'display_name': 'Puma Men Axis White & Grey Sports Shoes',
#  'gender': 'Men',
#  'image_id': 33822,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-D8Rm63c37pJbhdAXrExjAa">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-gCw9N97dKJmNeXPXApn94e" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">22198</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Timberland Men Black Casual Shoes',
#  'gender': 'Men',
#  'image_id': 22198,
#  'master_category': 'Footwear',
#  'season': 'Fall',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-gCw9N97dKJmNeXPXApn94e">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-FK5JfxLrUnmb8zorxARhCd" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">59435</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Formal Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Arrow Men Black Formal Shoes',
#  'gender': 'Men',
#  'image_id': 59435,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Formal',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-FK5JfxLrUnmb8zorxARhCd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-a6bcwsqmGqUsDWdrkDigkn" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">49461</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Blue',
#  'display_name': 'Vans Men Blue Era Scilla Plaid Shoes',
#  'gender': 'Men',
#  'image_id': 49461,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-a6bcwsqmGqUsDWdrkDigkn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-4e4mjZYm5GMT6VNQwBk4Xu" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">10268</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Formal Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Clarks Men Hang Work Leather Black Formal Shoes',
#  'gender': 'Men',
#  'image_id': 10268,
#  'master_category': 'Footwear',
#  'season': 'Fall',
#  'sub_category': 'Shoes',
#  'usage': 'Formal',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-4e4mjZYm5GMT6VNQwBk4Xu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ALAS2YGz2W5kGVTT99uH9F">
#         <div id="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F-Kr6XdmXFFE4HWxG96LYmCx" class="ipyplot-content-div-ALAS2YGz2W5kGVTT99uH9F">
#             <h4 style="font-size: 12px; word-wrap: break-word;">49495</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoe
#     <style>
#         #ipyplot-html-viewer-toggle-avGZ8yNFHvPucM6DpBh2Nn {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-avGZ8yNFHvPucM6DpBh2Nn {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-avGZ8yNFHvPucM6DpBh2Nn {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-avGZ8yNFHvPucM6DpBh2Nn:checked ~ #ipyplot-html-viewer-textarea-avGZ8yNFHvPucM6DpBh2Nn {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-avGZ8yNFHvPucM6DpBh2Nn:checked + #ipyplot-html-viewer-label-avGZ8yNFHvPucM6DpBh2Nn:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-avGZ8yNFHvPucM6DpBh2Nn">
#         <label id="ipyplot-html-viewer-label-avGZ8yNFHvPucM6DpBh2Nn" for="ipyplot-html-viewer-toggle-avGZ8yNFHvPucM6DpBh2Nn">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-avGZ8yNFHvPucM6DpBh2Nn" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Z36jESQ6p88sCBHPeVG8qH {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Z36jESQ6p88sCBHPeVG8qH">
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-JGcC7nAzMRC8CbZujSQryi" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">49495</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Khaki',
#  'display_name': 'Vans Men Khaki Shoes',
#  'gender': 'Men',
#  'image_id': 49495,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-JGcC7nAzMRC8CbZujSQryi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-PzS6YP8vhjkJcCdrW28dwW" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">10268</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Formal Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Clarks Men Hang Work Leather Black Formal Shoes',
#  'gender': 'Men',
#  'image_id': 10268,
#  'master_category': 'Footwear',
#  'season': 'Fall',
#  'sub_category': 'Shoes',
#  'usage': 'Formal',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-PzS6YP8vhjkJcCdrW28dwW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-LGzgbMch3xdVJLHAULfDX5" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">22198</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Timberland Men Black Casual Shoes',
#  'gender': 'Men',
#  'image_id': 22198,
#  'master_category': 'Footwear',
#  'season': 'Fall',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-LGzgbMch3xdVJLHAULfDX5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-UCdkbuMTHFMX2Xs7yBahHd" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">59435</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Formal Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Arrow Men Black Formal Shoes',
#  'gender': 'Men',
#  'image_id': 59435,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Formal',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-UCdkbuMTHFMX2Xs7yBahHd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-3Yn3CHeeGhGExTWGVoabEX" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">42089</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'White',
#  'display_name': 'ADIDAS Men White Corona Sports Shoes',
#  'gender': 'Men',
#  'image_id': 42089,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!
#         <style>
#         #ipyplot-imgs-container-div-Z36jESQ6p88sCBHPeVG8qH {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH]:target {
#             transform: scale(1.0);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Z36jESQ6p88sCBHPeVG8qH">
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-JGcC7nAzMRC8CbZujSQryi" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">49495</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Khaki',
#  'display_name': 'Vans Men Khaki Shoes',
#  'gender': 'Men',
#  'image_id': 49495,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-JGcC7nAzMRC8CbZujSQryi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-PzS6YP8vhjkJcCdrW28dwW" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">10268</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Formal Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Clarks Men Hang Work Leather Black Formal Shoes',
#  'gender': 'Men',
#  'image_id': 10268,
#  'master_category': 'Footwear',
#  'season': 'Fall',
#  'sub_category': 'Shoes',
#  'usage': 'Formal',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-PzS6YP8vhjkJcCdrW28dwW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-LGzgbMch3xdVJLHAULfDX5" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">22198</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Casual Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Timberland Men Black Casual Shoes',
#  'gender': 'Men',
#  'image_id': 22198,
#  'master_category': 'Footwear',
#  'season': 'Fall',
#  'sub_category': 'Shoes',
#  'usage': 'Casual',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-LGzgbMch3xdVJLHAULfDX5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-UCdkbuMTHFMX2Xs7yBahHd" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">59435</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Formal Shoes',
#  'base_colour': 'Black',
#  'display_name': 'Arrow Men Black Formal Shoes',
#  'gender': 'Men',
#  'image_id': 59435,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Formal',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-UCdkbuMTHFMX2Xs7yBahHd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-3Yn3CHeeGhGExTWGVoabEX" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">42089</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'White',
#  'display_name': 'ADIDAS Men White Corona Sports Shoes',
#  'gender': 'Men',
#  'image_id': 42089,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-3Yn3CHeeGhGExTWGVoabEX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-52DFp5AiariMiyYyMn94QN" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">33822</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_colour': 'White',
#  'display_name': 'Puma Men Axis White & Grey Sports Shoes',
#  'gender': 'Men',
#  'image_id': 33822,
#  'master_category': 'Footwear',
#  'season': 'Summer',
#  'sub_category': 'Shoes',
#  'usage': 'Sports',
#  'year': 2012}</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-52DFp5AiariMiyYyMn94QN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z36jESQ6p88sCBHPeVG8qH">
#         <div id="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH-gutEgSKLABufEbp9ArBNUY" class="ipyplot-content-div-Z36jESQ6p88sCBHPeVG8qH">
#             <h4 style="font-size: 12px; word-wrap: break-word;">34835</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;">{'article_type': 'Sports Shoes',
#  'base_c

# %% [markdown]
# ## Task 3:
#
# Run inference using the FashionNetVgg16NoBn from https://github.com/i008/pytorch-deepfashion.git on the original images in Step 1 or 2.

# %%
s3_target = perform_task({"s3_target": s3_target}, "predict")

with s3.open(f'{s3_target}/predictions.json') as f:
    predictions = json.load(f)

print(f'Number of predictions: {len(predictions)}')
print(f'Prediction output per image: massive_attr-{len(predictions[0]["massive_attr"][0])}, categories-{len(predictions[0]["categories"][0])}')
# Out:
# Number of predictions: 10
# Prediction output per image: massive_attr-1000, categories-50
